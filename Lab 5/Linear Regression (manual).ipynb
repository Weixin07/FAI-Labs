# %% [markdown]
# # Linear Regression

# %% [markdown]
# Linear regression shows the linear relationship between the independent variable (X-axis) and the dependent variable (Y-axis), hence called linear regression.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# %%
plt.scatter(x, y)
plt.title('Car')
plt.xlabel('Age')
plt.ylabel('Speed')
plt.show()

# %% [markdown]
# ## Drawing Linear Regression

# %%
from scipy import stats as sts

# %%
m, c, r, p, std_err = sts.linregress(x, y)

# %%
def line(x):
    return m * x + c

# %%
model = list(map(line, x))

# %%
plt.scatter(x, y)
plt.title('Car')
plt.xlabel('Age')
plt.ylabel('Speed')
plt.plot(x, model)
plt.show()

# %% [markdown]
# Correlation

# %%
r
# Out:
# -0.758591524376155

# %% [markdown]
# The result -0.76 shows that it is a negative correlation, it indicates that linear regression in future predictions.

# %% [markdown]
# ### Prediction using linear regression

# %%
speed = line(10)

# %%
speed
# Out:
# 85.59308314937454
