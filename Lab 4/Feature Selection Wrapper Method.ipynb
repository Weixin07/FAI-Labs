# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Wrapper Method

# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
df = pd.read_csv('wine.csv')

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %%
X = df.iloc[:, 0: 13]

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
y = df['target']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 21     12.93        3.80  2.65               18.6        102           2.41
# 24     13.50        1.81  2.61               20.0         96           2.53
# 72     13.49        1.66  2.24               24.0         87           1.88
# 157    12.45        3.03  2.64               27.0         97           1.90
# 111    12.52        2.43  2.17               21.0         88           2.55
# ..       ...         ...   ...                ...        ...            ...
# 38     13.07        1.50  2.10               15.5         98           2.40
# 112    11.76        2.68  2.92               20.0        103           1.75
# 168    13.58        2.58  2.69               24.5        105           1.55
# 6      14.39        1.87  2.45               14.6         96           2.50
# 133    12.70        3.55  2.36               21.5        106           1.70
#
# ...

# %%
X_test
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 171    12.77        2.39  2.28               19.5         86           1.39
# 138    13.49        3.59  2.19               19.5         88           1.62
# 36     13.28        1.64  2.84               15.5        110           2.60
# 141    13.36        2.56  2.35               20.0         89           1.40
# 172    14.16        2.51  2.48               20.0         91           1.68
# 75     11.66        1.88  1.92               16.0         97           1.61
# 119    12.00        3.43  2.00               19.0         87           2.00
# 55     13.56        1.73  2.46               20.5        116           2.96
# 148    13.32        3.24  2.38               21.5         92           1.93
# 122    12.42        4.43  2.73               26.5        102           2.20
# 85     12.67        0.98  2.24               18.0         99           2.20
# ...

# %%
y_train
# Out:
# 21     0
# 24     0
# 72     1
# 157    2
# 111    1
#       ..
# 38     0
# 112    1
# 168    2
# 6      0
# 133    2
# Name: target, Length: 142, dtype: int64

# %%
y_test
# Out:
# 171    2
# 138    2
# 36     0
# 141    2
# 172    2
# 75     1
# 119    1
# 55     0
# 148    2
# 122    1
# 85     1
# 150    2
# 145    2
# 135    2
# 71     1
# 88     1
# 109    1
# 93     1
# 167    2
# 16     0
# 103    1
# 15     0
# 159    2
# 152    2
# 25     0
# 114    1
# 161    2
# 31     0
# 175    2
# 104    1
# 143    2
# 23     0
# 63     1
# 163    2
# 45     0
# 110    1
# Name: target, dtype: int64

# %%
ffs = SequentialFeatureSelector(RandomForestClassifier(n_jobs = -1),
                                k_features = 6,
                                forward = True,
                                floating = False,
                                verbose = 2,
                                scoring = 'accuracy',
                                cv = 5)

# %%
ffs.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   24.1s finished
#
# [2023-10-04 09:24:38] Features: 1/6 -- score: 0.7310344827586207[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   13.8s finished
#
# [2023-10-04 09:24:52] Features: 2/6 -- score: 0.9157635467980297[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   12.9s finished
#
# [2023-10-04 09:25:05] Features: 3/6 -- score: 0.9721674876847292[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
ffs.k_feature_idx_
# Out:
# (0, 4, 6, 9, 10, 12)

# %%
ffs.k_feature_names_
# Out:
# ('alcohol', 'magnesium', 'flavanoids', 'color_intensity', 'hue', 'proline')

# %%
ffs.k_score_
# Out:
# 0.9859605911330049

# %%
pd.DataFrame.from_dict(ffs.get_metric_dict()).T
# Out:
#             feature_idx                                          cv_scores  \
# 1                  (6,)  [0.7931034482758621, 0.8620689655172413, 0.535...
# 2                (6, 9)  [0.896551724137931, 0.896551724137931, 0.92857...
# 3             (0, 6, 9)  [0.9310344827586207, 0.9655172413793104, 0.964...
# 4          (0, 4, 6, 9)  [0.9655172413793104, 0.9655172413793104, 0.964...
# 5      (0, 4, 6, 9, 12)  [0.9655172413793104, 0.9655172413793104, 1.0, ...
# 6  (0, 4, 6, 9, 10, 12)  [0.9655172413793104, 1.0, 1.0, 1.0, 0.96428571...
#
#   avg_score                                      feature_names  ci_bound  \
# 1  0.731034                                      (flavanoids,)  0.140577
# 2  0.915764                      (flavanoids, color_intensity)  0.020162
# 3  0.972167             (alcohol, flavanoids, color_intensity)  0.033257
# 4  0.979064  (alcohol, magnesium, flavanoids, color_intensity)  0.021979
# 5  0.979064  (alcohol, magnesium, flavanoids, color_intensi...  0.021979
# ...

# %% [markdown]
# ## Topic 2: Backward Elimination

# %%
bfe = SequentialFeatureSelector(RandomForestClassifier(n_jobs = -1),
                                k_features = 6,
                                forward = False,
                                floating = False,
                                verbose = 2,
                                scoring = 'accuracy',
                                cv = 5)

# %%
bfe.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   15.6s finished
#
# [2023-10-04 09:28:09] Features: 12/6 -- score: 0.9857142857142858[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   14.8s finished
#
# [2023-10-04 09:28:24] Features: 11/6 -- score: 0.9857142857142858[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   13.9s finished
#
# [2023-10-04 09:28:38] Features: 10/6 -- score: 0.9857142857142858[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
bfe.k_feature_idx_
# Out:
# (0, 1, 3, 9, 10, 12)

# %%
bfe.k_feature_names_
# Out:
# ('alcohol',
#  'malic_acid',
#  'alcalinity_of_ash',
#  'color_intensity',
#  'hue',
#  'proline')

# %%
bfe.k_score_
# Out:
# 0.9790640394088669

# %%
bfe = SequentialFeatureSelector(RandomForestClassifier(n_jobs = -1),
                                k_features = (1, 13),
                                forward = False,
                                floating = False,
                                verbose = 2,
                                scoring = 'accuracy',
                                cv = 5)

# %%
bfe.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   16.3s finished
#
# [2023-10-04 09:33:14] Features: 12/1 -- score: 0.9857142857142858[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   13.6s finished
#
# [2023-10-04 09:33:27] Features: 11/1 -- score: 0.9928571428571429[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   13.9s finished
#
# [2023-10-04 09:33:41] Features: 10/1 -- score: 0.9859605911330049[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %% [markdown]
# ### Topic 3: Exhaustive Feature Selector

# %%
df2 = pd.read_csv('sampledata.csv')

# %%
df2.head()
# Out:
#     age  gender  height  weight  target
# 0  1.71       1    15.6     127       0
# 1  1.78       1    11.2     100       0
# 2  2.36       0    18.6     101       0
# 3  1.95       1    16.8     113       0
# 4  2.59       0    21.0     118       0

# %%
df2.shape
# Out:
# (178, 5)

# %%
df2.isnull().sum()
# Out:
# age       0
# gender    0
# height    0
# weight    0
# target    0
# dtype: int64

# %%
X = df2.drop('target', axis = 1)

# %%
y = df2['target']

# %%
X.head()
# Out:
#     age  gender  height  weight
# 0  1.71       1    15.6     127
# 1  1.78       1    11.2     100
# 2  2.36       0    18.6     101
# 3  1.95       1    16.8     113
# 4  2.59       0    21.0     118

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train
# Out:
#       age  gender  height  weight
# 99   3.17       0    18.0      88
# 34   1.80       1    19.0     110
# 96   2.12       0    21.5     134
# 91   1.51       1    22.0      86
# 120  2.40       1    20.0      96
# ..    ...     ...     ...     ...
# 155  5.19       0    22.0      93
# 41   3.84       1    18.8      90
# 146  5.04       1    20.0      80
# 148  3.24       1    21.5      92
# 123  5.80       1    21.5      86
#
# [142 rows x 4 columns]

# %%
y_train
# Out:
# 99     1
# 34     0
# 96     1
# 91     1
# 120    1
#       ..
# 155    2
# 41     0
# 146    2
# 148    2
# 123    1
# Name: target, Length: 142, dtype: int64

# %%
X_test
# Out:
#       age  gender  height  weight
# 158  1.68       1    25.0      98
# 2    2.36       0    18.6     101
# 20   1.63       0    16.0     126
# 94   1.99       0    18.0      98
# 88   2.06       0    21.6      84
# 43   3.98       1    17.5     103
# 162  3.27       0    22.0     106
# 177  4.10       0    24.5      96
# 111  2.43       1    21.0      88
# 163  3.45       1    18.5     106
# 137  5.51       1    25.0      96
# 7    2.15       0    17.6     121
# 80   0.92       1    19.0      86
# 108  1.29       0    19.0      92
# 59   0.94       0    10.6      88
# 167  3.37       0    19.5      88
# 103  1.72       1    19.5      86
# 139  2.96       1    24.0     101
# 92   1.53       1    20.7      80
# 118  3.43       1    16.0      80
# 30   1.50       1    22.5     101
# 78   0.99       1    14.8     136
# 113  0.74       1    21.0      88
# 46   3.59       0    16.0     102
# 122  4.43       0    26.5     102
# 35   1.81       0    20.5     100
# ...

# %%
y_test
# Out:
# 158    2
# 2      0
# 20     0
# 94     1
# 88     1
# 43     0
# 162    2
# 177    2
# 111    1
# 163    2
# 137    2
# 7      0
# 80     1
# 108    1
# 59     1
# 167    2
# 103    1
# 139    2
# 92     1
# 118    1
# 30     0
# 78     1
# 113    1
# 46     0
# 122    1
# 35     0
# 67     1
# 73     1
# 49     0
# 161    2
# 168    2
# 52     0
# 173    2
# 174    2
# 172    2
# 101    1
# Name: target, dtype: int64

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector

# %%
efs = ExhaustiveFeatureSelector(RandomForestClassifier(n_jobs = -1),
                               min_features = 1,
                               max_features = 4,
                               scoring = 'accuracy',
                               cv = 2,
                               n_jobs = -1)

# %%
efs.fit(X_train, y_train)
# Out:
# Features: 15/15
# ExhaustiveFeatureSelector(cv=2, estimator=RandomForestClassifier(n_jobs=-1),
#                           feature_groups=[[0], [1], [2], [3]], max_features=4,
#                           n_jobs=-1)

# %%
efs.best_feature_names_
# Out:
# ('age', 'height', 'weight')

# %%
efs.best_score_
# Out:
# 0.7112676056338028

# %%
pd.DataFrame.from_dict(efs.get_metric_dict()).T
# Out:
#      feature_idx                                  cv_scores avg_score  \
# 0           (0,)   [0.5774647887323944, 0.4647887323943662]  0.521127
# 1           (1,)   [0.3380281690140845, 0.4084507042253521]  0.373239
# 2           (2,)   [0.5774647887323944, 0.5633802816901409]  0.570423
# 3           (3,)  [0.4507042253521127, 0.38028169014084506]  0.415493
# 4         (0, 1)   [0.4788732394366197, 0.4647887323943662]  0.471831
# 5         (0, 2)    [0.6338028169014085, 0.647887323943662]  0.640845
# 6         (0, 3)   [0.6197183098591549, 0.6197183098591549]  0.619718
# 7         (1, 2)  [0.5352112676056338, 0.49295774647887325]  0.514085
# 8         (1, 3)   [0.4084507042253521, 0.5070422535211268]  0.457746
# 9         (2, 3)   [0.5915492957746479, 0.6619718309859155]  0.626761
# 10     (0, 1, 2)   [0.5915492957746479, 0.6338028169014085]  0.612676
# 11     (0, 1, 3)    [0.5915492957746479, 0.647887323943662]  0.619718
# ...
